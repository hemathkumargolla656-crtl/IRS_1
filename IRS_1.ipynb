# %% [markdown]
# <a href="https://colab.research.google.com/github/hemathkumargolla656-crtl/IRS_1/blob/main/IRS_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
doc1 = "Machine learning is a branch of artifical intelligence that focuses on building applications that learn from data."
doc2 = "Artifical intelligence and machine learning are widely used to make smart applications based on data."
doc3 = "Machine learning is a subset of Artifcal intelligence."
documents = [doc1,doc2,doc3]
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(documents)
similarity_score = cosine_similarity(tfidf_matrix[0:1],tfidf_matrix[1:2],)[0][0]
print("cosine similarity between document 1 and document 2.")
print(f"{similarity_score:4f}")
# Out:
# cosine similarity between document 1 and document 2.
# 0.382915

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
doc1 = "Artifical intelligence And Machine Learning."
doc2 = "Artifical intelligence And Machine Learning."
doc3 = "Machine learning is a subset of Artifcal intelligence."
documents = [doc1,doc2]
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(documents)
similarity_score = cosine_similarity(tfidf_matrix[0:1],tfidf_matrix[1:2])[0][0]
print("cosine similarity between document 1 and document 2.")
print(f"{similarity_score:4f}")
# Out:
# cosine similarity between document 1 and document 2.
# 1.000000

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
doc1 = "bhaggi is a good girl."
doc2 = "Artifical intelligence and machine learning ."
doc3 = "maheshwari is a boy."
documents = [doc1,doc2]
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(documents)
similarity_score = cosine_similarity(tfidf_matrix[0:1],tfidf_matrix[1:2])[0][0]
print("cosine similarity between document 1 and document 2.")
print(f"{similarity_score:4f}")
# Out:
# cosine similarity between document 1 and document 2.
# 0.000000
