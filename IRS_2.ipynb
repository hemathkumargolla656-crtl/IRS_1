# %% [markdown]
# <a href="https://colab.research.google.com/github/hemathkumargolla656-crtl/IRS_1/blob/main/IRS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
text = "Text processing is an important task in natural language processing and data analysis."
words = nltk.word_tokenize(text)
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()
processed_words = []
for word in words:
   word = word.lower()
   if word.isalpha() and word not in stop_words:
    stemmed = stemmer.stem(word)
    processed_words.append(stemmed)
    print("Original Text:")
    print(text)
    print("\nProcessed Words (After Stopword Removal and Stemming):")
print(processed_words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Original Text:
# Text processing is an important task in natural language processing and data analysis.
#
# Processed Words (After Stopword Removal and Stemming):
# Original Text:
# Text processing is an important task in natural language processing and data analysis.
#
# Processed Words (After Stopword Removal and Stemming):
# Original Text:
# Text processing is an important task in natural language processing and data analysis.
#
# Processed Words (After Stopword Removal and Stemming):
# Original Text:
# Text processing is an important task in natural language processing and data analysis.
#
# ...
